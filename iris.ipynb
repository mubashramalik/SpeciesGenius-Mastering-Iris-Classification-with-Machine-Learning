# %% [markdown]
# # import Libraries

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# # import data

# %%
iris= pd.read_csv('Iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # tail

# %%
iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# # describe

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # Drop

# %%
new_iris= iris.drop(columns=['Id'])
new_iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # info

# %%
new_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # cleaning data

# %%
new_iris.dropna()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Species Count

# %%
iris['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
sns.barplot(new_iris)
plt.show()

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(new_iris)
# Out:
# c:\Users\Hp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Scatter plot for SepalLengthCm and SepalWidthCm

# %%
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', data=new_iris)
plt.show()

# %% [markdown]
# # Scatter plot for PetalLengthCm and PetalWidthCm

# %%
sns.scatterplot(x='PetalLengthCm', y='PetalWidthCm', data=new_iris)
plt.show()

# %% [markdown]
# # Countplot

# %%
sns.countplot(x='Species',data=new_iris)
plt.show()

# %% [markdown]
# # Specifyinghuecolors

# %%
hue_colors={"Iris-setosa":"blue","Iris-versicolor":"orange","Iris-virginica":"green"}
sns.scatterplot(x='PetalLengthCm', y='PetalWidthCm', data=iris,hue='Species',palette=hue_colors)
plt.show()

# %% [markdown]
# # Usinghuewithcountplots

# %%
sns.countplot(x='Species',data=new_iris,hue='Species')
plt.show()

# %% [markdown]
# # Label Encoding

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder() 
new_iris['Species']= label_encoder.fit_transform(new_iris['Species'])
new_iris['Species'].unique()
# Out:
# array([0, 1, 2])

# %% [markdown]
# # Slicing Data

# %%
X=new_iris[['SepalLengthCm','SepalWidthCm','PetalLengthCm','SepalWidthCm']]
Y=new_iris['Species']

# %% [markdown]
# # Spliting data into training set

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.30,random_state=0)

# %% [markdown]
# # Implement Models and Show Accuracy,Precision,Recall and F1-Score

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Create a list of classifiers
classifiers = [
    ('Logistic Regression', LogisticRegression()),
    ('Decision Tree', DecisionTreeClassifier()),
    ('Random Forest', RandomForestClassifier())
]

# Iterate through the classifiers and evaluate their accuracy, precision, recall, and F1-score
for name, clf in classifiers:
    clf.fit(x_train, y_train)
    y_pred = clf.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')  # Use 'weighted' for multiclass
    recall = recall_score(y_test, y_pred, average='weighted')  # Use 'weighted' for multiclass
    f1 = f1_score(y_test, y_pred, average='weighted')  # Use 'weighted' for multiclass
    
    print(f'Classifier: {name}')
    print(f'Accuracy: {accuracy:.2f}')
    print(f'Precision: {precision:.2f}')
    print(f'Recall: {recall:.2f}')
    print(f'F1 Score: {f1:.2f}')
    print()
# Out:
# Classifier: Logistic Regression
# Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
# F1 Score: 0.96
#
# Classifier: Decision Tree
# Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
# F1 Score: 0.96
#
# Classifier: Random Forest
# Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
# F1 Score: 0.96

# %% [markdown]
# # Classifier Accuracy Models

# %%
classifier_names = []
accuracies = []


for name, clf in classifiers:
    clf.fit(x_train, y_train)
    y_pred = clf.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    classifier_names.append(name)
    accuracies.append(accuracy)

# Create a bar chart to visualize classifier accuracies
plt.figure(figsize=(8, 6))
plt.bar(classifier_names, accuracies, color=['blue', 'green', 'red'])
plt.xlabel('Classifier')
plt.ylabel('Accuracy')
plt.title('Classifier Accuracy Comparison')
plt.ylim([0, 1])
plt.show()
